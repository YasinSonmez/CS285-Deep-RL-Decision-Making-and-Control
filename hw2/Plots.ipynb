# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

# %%
# Read the csv file
data_path = "data/Plot_data/"
_Eval_AverageEpLen
_EnvstepsSoFar

# %%
cartpole_Train_EnvstepsSoFar = pd.read_csv(data_path + "data_q2_pg_cartpole_CartPole-v0_21-09-2023_15-47-43_Train_EnvstepsSoFar.csv")["Value"]
cartpole_Eval_AverageReturn = pd.read_csv(data_path + "data_q2_pg_cartpole_CartPole-v0_21-09-2023_15-47-43_Eval_AverageReturn.csv")["Value"]

cartpole_na_Train_EnvstepsSoFar = pd.read_csv(data_path + "data_q2_pg_cartpole_na_CartPole-v0_21-09-2023_15-56-42_Train_EnvstepsSoFar.csv")["Value"]
cartpole_na_Eval_AverageReturn = pd.read_csv(data_path + "data_q2_pg_cartpole_na_CartPole-v0_21-09-2023_15-56-42_Eval_AverageReturn.csv")["Value"]

cartpole_rtg_Train_EnvstepsSoFar = pd.read_csv(data_path + "data_q2_pg_cartpole_rtg_CartPole-v0_21-09-2023_15-48-04_Train_EnvstepsSoFar.csv")["Value"]
cartpole_rtg_Eval_AverageReturn = pd.read_csv(data_path + "data_q2_pg_cartpole_rtg_CartPole-v0_21-09-2023_15-48-04_Eval_AverageReturn.csv")["Value"]

cartpole_rtg_na_Train_EnvstepsSoFar = pd.read_csv(data_path + "data_q2_pg_cartpole_rtg_na_CartPole-v0_21-09-2023_15-57-07_Train_EnvstepsSoFar.csv")["Value"]
cartpole_rtg_na_Eval_AverageReturn = pd.read_csv(data_path + "data_q2_pg_cartpole_rtg_na_CartPole-v0_21-09-2023_15-57-07_Eval_AverageReturn.csv")["Value"]

cartpole_lb_Train_EnvstepsSoFar = pd.read_csv(data_path + "data_q2_pg_cartpole_lb_CartPole-v0_21-09-2023_15-57-38_Train_EnvstepsSoFar.csv")["Value"]
cartpole_lb_Eval_AverageReturn = pd.read_csv(data_path + "data_q2_pg_cartpole_lb_CartPole-v0_21-09-2023_15-57-38_Eval_AverageReturn.csv")["Value"]

cartpole_lb_na_Train_EnvstepsSoFar = pd.read_csv(data_path + "data_q2_pg_cartpole_lb_na_CartPole-v0_21-09-2023_15-59-22_Train_EnvstepsSoFar.csv")["Value"]
cartpole_lb_na_Eval_AverageReturn = pd.read_csv(data_path + "data_q2_pg_cartpole_lb_na_CartPole-v0_21-09-2023_15-59-22_Eval_AverageReturn.csv")["Value"]

cartpole_lb_rtg_Train_EnvstepsSoFar = pd.read_csv(data_path + "data_q2_pg_cartpole_lb_rtg_CartPole-v0_21-09-2023_15-58-32_Train_EnvstepsSoFar.csv")["Value"]
cartpole_lb_rtg_Eval_AverageReturn = pd.read_csv(data_path + "data_q2_pg_cartpole_lb_rtg_CartPole-v0_21-09-2023_15-58-32_Eval_AverageReturn.csv")["Value"]

cartpole_lb_rtg_na_Train_EnvstepsSoFar = pd.read_csv(data_path + "data_q2_pg_cartpole_lb_rtg_na_CartPole-v0_21-09-2023_16-00-01_Train_EnvstepsSoFar.csv")["Value"]
cartpole_lb_rtg_na_Eval_AverageReturn = pd.read_csv(data_path + "data_q2_pg_cartpole_lb_rtg_na_CartPole-v0_21-09-2023_16-00-01_Eval_AverageReturn.csv")["Value"]

# %%
plt.figure(figsize=(10, 7))
plt.plot(cartpole_Train_EnvstepsSoFar, cartpole_Eval_AverageReturn, label="PG")
plt.plot(cartpole_na_Train_EnvstepsSoFar, cartpole_na_Eval_AverageReturn, label="PG+NA")
plt.plot(cartpole_rtg_Train_EnvstepsSoFar, cartpole_rtg_Eval_AverageReturn, label="PG+RTG")
plt.plot(cartpole_rtg_na_Train_EnvstepsSoFar, cartpole_rtg_na_Eval_AverageReturn, label="PG+NA+RTG")
plt.xlabel("Environment Steps")
plt.ylabel("Eval Average Return")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 7))
plt.plot(cartpole_lb_Train_EnvstepsSoFar, cartpole_lb_Eval_AverageReturn, label="PG")
plt.plot(cartpole_lb_na_Train_EnvstepsSoFar, cartpole_lb_na_Eval_AverageReturn, label="PG+NA")
plt.plot(cartpole_lb_rtg_Train_EnvstepsSoFar, cartpole_lb_rtg_Eval_AverageReturn, label="PG+RTG")
plt.plot(cartpole_lb_rtg_na_Train_EnvstepsSoFar, cartpole_lb_rtg_na_Eval_AverageReturn, label="PG+NA+RTG")
plt.xlabel("Environment Steps")
plt.ylabel("Eval Average Return")
plt.legend()
plt.show()

# %%
cheetah_Train_EnvstepsSoFar = pd.read_csv(data_path + "data_q2_pg_cheetah_HalfCheetah-v4_22-09-2023_10-05-26_Train_EnvstepsSoFar.csv")["Value"]
cheetah_Eval_AverageReturn = pd.read_csv(data_path + "data_q2_pg_cheetah_HalfCheetah-v4_22-09-2023_10-05-26_Eval_AverageReturn.csv")["Value"]

cheetah_bsg5_Train_EnvstepsSoFar = pd.read_csv(data_path + "data_q2_pg_cheetah_baseline_HalfCheetah-v4_22-09-2023_10-08-13_Train_EnvstepsSoFar_bsg5.csv")["Value"]
cheetah_bsg5_Eval_AverageReturn = pd.read_csv(data_path + "data_q2_pg_cheetah_baseline_HalfCheetah-v4_22-09-2023_10-08-13_Eval_AverageReturn_bsg5.csv")["Value"]
cheetah_bsg5_Baseline_Loss = pd.read_csv(data_path + "data_q2_pg_cheetah_baseline_HalfCheetah-v4_22-09-2023_10-08-13_baseline_loss_bsg5.csv")["Value"]

cheetah_bsg2_Train_EnvstepsSoFar = pd.read_csv(data_path + "data_q2_pg_cheetah_baseline_HalfCheetah-v4_22-09-2023_10-12-01_Train_EnvstepsSoFar_bsg2.csv")["Value"]
cheetah_bsg2_Eval_AverageReturn = pd.read_csv(data_path + "data_q2_pg_cheetah_baseline_HalfCheetah-v4_22-09-2023_10-12-01_Eval_AverageReturn_bsg2.csv")["Value"]
cheetah_bsg2_Baseline_Loss = pd.read_csv(data_path + "data_q2_pg_cheetah_baseline_HalfCheetah-v4_22-09-2023_10-12-01_baseline_loss_bsg2.csv")["Value"]

# %%
plt.figure(figsize=(10, 7))
plt.plot(cheetah_bsg5_Train_EnvstepsSoFar, cheetah_bsg5_Baseline_Loss)
#plt.plot(cheetah_bsg2_Train_EnvstepsSoFar, cheetah_bsg2_Baseline_Loss, label="BGS=2")
plt.xlabel("Environment Steps")
plt.ylabel("Baseline Loss")
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(10, 7))
plt.plot(cheetah_Train_EnvstepsSoFar, cheetah_Eval_AverageReturn, label="No Baseline")
plt.plot(cheetah_bsg5_Train_EnvstepsSoFar, cheetah_bsg5_Eval_AverageReturn, label="Baseline")
plt.xlabel("Environment Steps")
plt.ylabel("Eval Return")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 7))
plt.plot(cheetah_bsg5_Train_EnvstepsSoFar, cheetah_bsg5_Baseline_Loss, label="BGS=5")
plt.plot(cheetah_bsg2_Train_EnvstepsSoFar, cheetah_bsg2_Baseline_Loss, label="BGS=2")
plt.xlabel("Environment Steps")
plt.ylabel("Baseline Loss")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 7))
plt.plot(cheetah_bsg5_Train_EnvstepsSoFar, cheetah_bsg5_Eval_AverageReturn, label="BGS=5")
plt.plot(cheetah_bsg2_Train_EnvstepsSoFar, cheetah_bsg2_Eval_AverageReturn, label="BGS=2")
plt.xlabel("Environment Steps")
plt.ylabel("Eval Return")
plt.legend()
plt.show()

# %%
lander_lambda0_Train_EnvstepsSoFar = pd.read_csv(data_path + "data_q2_pg_lunar_lander_lambda0_Train_EnvstepsSoFar.csv")["Value"]
lander_lambda0_Eval_AverageReturn = pd.read_csv(data_path + "data_q2_pg_lunar_lander_lambda0_Eval_AverageReturn.csv")["Value"]
lander_lambda0_Baseline_Loss = pd.read_csv(data_path + "data_q2_pg_lunar_lander_lambda0_Baseline_Loss.csv")["Value"]

lander_lambda095_Train_EnvstepsSoFar = pd.read_csv(data_path + "data_q2_pg_lunar_lander_lambda0.95_Train_EnvstepsSoFar.csv")["Value"]
lander_lambda095_Eval_AverageReturn = pd.read_csv(data_path + "data_q2_pg_lunar_lander_lambda0.95_Eval_AverageReturn.csv")["Value"]
lander_lambda095_Baseline_Loss = pd.read_csv(data_path + "data_q2_pg_lunar_lander_lambda0.95_Baseline_Loss.csv")["Value"]

lander_lambda098_Train_EnvstepsSoFar = pd.read_csv(data_path + "data_q2_pg_lunar_lander_lambda0.98_Train_EnvstepsSoFar.csv")["Value"]
lander_lambda098_Eval_AverageReturn = pd.read_csv(data_path + "data_q2_pg_lunar_lander_lambda0.98_Eval_AverageReturn.csv")["Value"]
lander_lambda098_Baseline_Loss = pd.read_csv(data_path + "data_q2_pg_lunar_lander_lambda0.98_Baseline_Loss.csv")["Value"]

lander_lambda099_Train_EnvstepsSoFar = pd.read_csv(data_path + "data_q2_pg_lunar_lander_lambda0.99_Train_EnvstepsSoFar.csv")["Value"]
lander_lambda099_Eval_AverageReturn = pd.read_csv(data_path + "data_q2_pg_lunar_lander_lambda0.99_Eval_AverageReturn.csv")["Value"]
lander_lambda099_Baseline_Loss = pd.read_csv(data_path + "data_q2_pg_lunar_lander_lambda0.99_Baseline_Loss.csv")["Value"]

lander_lambda1_Train_EnvstepsSoFar = pd.read_csv(data_path + "data_q2_pg_lunar_lander_lambda1_Train_EnvstepsSoFar.csv")["Value"]
lander_lambda1_Eval_AverageReturn = pd.read_csv(data_path + "data_q2_pg_lunar_lander_lambda1_Eval_AverageReturn.csv")["Value"]
lander_lambda1_Baseline_Loss = pd.read_csv(data_path + "data_q2_pg_lunar_lander_lambda1_Baseline_Loss.csv")["Value"]

# %%
plt.figure(figsize=(10, 7))
plt.plot(lander_lambda0_Train_EnvstepsSoFar, lander_lambda0_Eval_AverageReturn, label="$\lambda = 0$")
plt.plot(lander_lambda095_Train_EnvstepsSoFar, lander_lambda095_Eval_AverageReturn, label="$\lambda = 0.95$")
plt.plot(lander_lambda098_Train_EnvstepsSoFar, lander_lambda098_Eval_AverageReturn, label="$\lambda = 0.98$")
plt.plot(lander_lambda099_Train_EnvstepsSoFar, lander_lambda099_Eval_AverageReturn, label="$\lambda = 0.99$")
plt.plot(lander_lambda1_Train_EnvstepsSoFar, lander_lambda1_Eval_AverageReturn, label="$\lambda = 1$")
plt.xlabel("Environment Steps")
plt.ylabel("Eval Return")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 7))
plt.plot(lander_lambda0_Train_EnvstepsSoFar, lander_lambda0_Baseline_Loss, label="$\lambda = 0$")
plt.plot(lander_lambda095_Train_EnvstepsSoFar, lander_lambda095_Baseline_Loss, label="$\lambda = 0.95$")
plt.plot(lander_lambda098_Train_EnvstepsSoFar, lander_lambda098_Baseline_Loss, label="$\lambda = 0.98$")
plt.plot(lander_lambda099_Train_EnvstepsSoFar, lander_lambda099_Baseline_Loss, label="$\lambda = 0.99$")
plt.plot(lander_lambda1_Train_EnvstepsSoFar, lander_lambda1_Baseline_Loss, label="$\lambda = 1$")
plt.xlabel("Environment Steps")
plt.ylabel("Baseline Loss")
plt.legend()
plt.show()

# %%
pendulum_default_s1_return = pd.read_csv(data_path + "data_q2_pg_pendulum_default_s1_return.csv")["Value"]
pendulum_default_s2_return = pd.read_csv(data_path + "data_q2_pg_pendulum_default_s2_return.csv")["Value"]
pendulum_default_s3_return = pd.read_csv(data_path + "data_q2_pg_pendulum_default_s3_return.csv")["Value"]
pendulum_default_s4_return = pd.read_csv(data_path + "data_q2_pg_pendulum_default_s4_return.csv")["Value"]
pendulum_default_s5_return = pd.read_csv(data_path + "data_q2_pg_pendulum_default_s5_return.csv")["Value"]

pendulum_default_s1_steps = pd.read_csv(data_path + "data_q2_pg_pendulum_default_s1_steps.csv")["Value"]
pendulum_default_s2_steps = pd.read_csv(data_path + "data_q2_pg_pendulum_default_s2_steps.csv")["Value"]
pendulum_default_s3_steps = pd.read_csv(data_path + "data_q2_pg_pendulum_default_s3_steps.csv")["Value"]
pendulum_default_s4_steps = pd.read_csv(data_path + "data_q2_pg_pendulum_default_s4_steps.csv")["Value"]
pendulum_default_s5_steps = pd.read_csv(data_path + "data_q2_pg_pendulum_default_s5_steps.csv")["Value"]

pendulum_hp_s1_return = pd.read_csv(data_path + "data_q2_pg_pendulum_hp_s1_return.csv")["Value"]
pendulum_hp_s2_return = pd.read_csv(data_path + "data_q2_pg_pendulum_hp_s2_return.csv")["Value"]
pendulum_hp_s3_return = pd.read_csv(data_path + "data_q2_pg_pendulum_hp_s3_return.csv")["Value"]
pendulum_hp_s4_return = pd.read_csv(data_path + "data_q2_pg_pendulum_hp_s4_return.csv")["Value"]
pendulum_hp_s5_return = pd.read_csv(data_path + "data_q2_pg_pendulum_hp_s5_return.csv")["Value"]

pendulum_hp_s1_steps = pd.read_csv(data_path + "data_q2_pg_pendulum_hp_s1_steps.csv")["Value"]
pendulum_hp_s2_steps = pd.read_csv(data_path + "data_q2_pg_pendulum_hp_s2_steps.csv")["Value"]
pendulum_hp_s3_steps = pd.read_csv(data_path + "data_q2_pg_pendulum_hp_s3_steps.csv")["Value"]
pendulum_hp_s4_steps = pd.read_csv(data_path + "data_q2_pg_pendulum_hp_s4_steps.csv")["Value"]
pendulum_hp_s5_steps = pd.read_csv(data_path + "data_q2_pg_pendulum_hp_s5_steps.csv")["Value"]

# %%
default_array = []
default_array.append(np.interp(x, pendulum_default_s1_steps, pendulum_default_s1_return))
default_array.append(np.interp(x, pendulum_default_s2_steps, pendulum_default_s2_return))
default_array.append(np.interp(x, pendulum_default_s3_steps, pendulum_default_s3_return))
default_array.append(np.interp(x, pendulum_default_s4_steps, pendulum_default_s4_return))
default_array.append(np.interp(x, pendulum_default_s5_steps, pendulum_default_s5_return))
default_array = np.array(default_array)

hp_array = []
hp_array.append(np.interp(x, pendulum_hp_s1_steps, pendulum_hp_s1_return))
hp_array.append(np.interp(x, pendulum_hp_s2_steps, pendulum_hp_s2_return))
hp_array.append(np.interp(x, pendulum_hp_s3_steps, pendulum_hp_s3_return))
hp_array.append(np.interp(x, pendulum_hp_s4_steps, pendulum_hp_s4_return))
hp_array.append(np.interp(x, pendulum_hp_s5_steps, pendulum_hp_s5_return))
hp_array = np.array(hp_array)

# %%
#calculating mean and standard deviation
default_array_mean=np.mean(default_array,axis=0)
default_array_std=np.std(default_array,axis=0)
#calculating mean and standard deviation
hp_array_mean=np.mean(hp_array,axis=0)
hp_array_std=np.std(hp_array,axis=0)

# %%
x = np.linspace(1,5e5, 1000000)
plt.figure(figsize=(10, 7))
plt.plot(x, default_array_mean, label='Mean')
plt.fill_between(x, default_array_mean - default_array_std, default_array_mean + default_array_std, alpha=0.2, label='Mean ± Std')
plt.plot(x, hp_array_mean, label='HP Mean')
plt.fill_between(x, hp_array_mean - hp_array_std, hp_array_mean + hp_array_std, alpha=0.2, label='HP Mean ± Std')
plt.xlabel("Environment Steps")
plt.ylabel("Eval Return")
plt.legend()
plt.show()
